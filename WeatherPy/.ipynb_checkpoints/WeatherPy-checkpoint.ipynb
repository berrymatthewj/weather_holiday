# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
from pprint import pprint
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Import API key
from config import weather_api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_units = "imperial"
#Import API key
# from config import weather_api_key
weather_api_key="dfc2727692557b5a27a7378f50f6abae"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={query_units}&q="

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={query_units}&q="

lat = []
lon = []
max_temp = []
country = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
time_zone = []
date_and_time = []
found_cities=[]

for i, city in enumerate(cities):
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        country.append(response["sys"]["country"])
        time_zone.append(response["timezone"])
        date_and_time.append(response["dt"])
        found_cities.append(city)
        print(f"Processing Record {i+1}: {city} found: appending data")
    except Exception:
        print(f"Processing Record {i+1}: {city} not found: skipping...")
else:
    print("Data Retrieval Complete")
# Out:
# Processing Record 1: saint-philippe found: appending data
# Processing Record 2: norman wells found: appending data
# Processing Record 3: port hedland found: appending data
# Processing Record 4: acapulco found: appending data
# Processing Record 5: chuy found: appending data
# Processing Record 6: havelock found: appending data
# Processing Record 7: port alfred found: appending data
# Processing Record 8: druzhba found: appending data
# Processing Record 9: estelle found: appending data
# Processing Record 10: rikitea found: appending data
# Processing Record 11: milkovo found: appending data
# Processing Record 12: kalispell found: appending data
# Processing Record 13: baykit found: appending data
# Processing Record 14: lorengau found: appending data
# Processing Record 15: qaanaaq found: appending data
# Processing Record 16: east london found: appending data
# Processing Record 17: mataura found: appending data
# Processing Record 18: bredasdorp found: appending data
# Processing Record 19: geraldton found: appending data
# Processing Record 20: castro found: appending data
# Processing Record 21: barrow found: appending data
# Processing Record 22: illoqqortoormiut not found: skipping...
# Processing Record 23: albany found: appending data
# Processing Record 24: grand river south east not found: skipping...
# Processing Record 25: margate found: appending data
# Processing Record 26: busselton found: appending data
# Processing Record 27: port elizabeth found: appending data
# Processing Record 28: leningradskiy found: appending data
# Processing Record 29: vaini found: appending data
# Processing Record 30: iqaluit found: appending data
# Processing Record 31: broken hill found: appending data
# Processing Record 32: puerto ayora found: appending data
# Processing Record 33: nortelandia found: appending data
# Processing Record 34: dongsheng found: appending data
# Processing Record 35: punta arenas found: appending data
# Processing Record 36: olinda found: appending data
# Processing Record 37: tiznit found: appending data
# Processing Record 38: bluff found: appending data
# Processing Record 39: tomatlan found: appending data
# Processing Record 40: longyearbyen found: appending data
# Processing Record 41: georgetown found: appending data
# Processing Record 42: stephenville found: appending data
# Processing Record 43: imbituba found: appending data
# Processing Record 44: zhanakorgan found: appending data
# Processing Record 45: rawannawi not found: skipping...
# Processing Record 46: karratha found: appending data
# Processing Record 47: lichinga found: appending data
# Processing Record 48: dikson found: appending data
# Processing Record 49: piryetos not found: skipping...
# Processing Record 50: abu samrah found: appending data
# Processing Record 51: maumere found: appending data
# Processing Record 52: mahebourg found: appending data
# Processing Record 53: tubruq not found: skipping...
# Processing Record 54: belushya guba not found: skipping...
# Processing Record 55: kodiak found: appending data
# Processing Record 56: torbay found: appending data
# Processing Record 57: katsuura found: appending data
# Processing Record 58: ancud found: appending data
# Processing Record 59: klaksvik found: appending data
# Processing Record 60: vanimo found: appending data
# Processing Record 61: yerbogachen found: appending data
# Processing Record 62: nguiu not found: skipping...
# Processing Record 63: namibe found: appending data
# Processing Record 64: standerton found: appending data
# Processing Record 65: butaritari found: appending data
# Processing Record 66: saskylakh found: appending data
# Processing Record 67: northam found: appending data
# Processing Record 68: cape town found: appending data
# Processing Record 69: bengkulu found: appending data
# Processing Record 70: faya found: appending data
# Processing Record 71: alugan found: appending data
# Processing Record 72: pierre found: appending data
# Processing Record 73: nizhneyansk not found: skipping...
# Processing Record 74: vilyuysk found: appending data
# Processing Record 75: atuona found: appending data
# Processing Record 76: tevaitoa found: appending data
# Processing Record 77: thompson found: appending data
# Processing Record 78: djambala found: appending data
# Processing Record 79: yumen found: appending data
# Processing Record 80: padang found: appending data
# Processing Record 81: avarua found: appending data
# Processing Record 82: viligili not found: skipping...
# Processing Record 83: kapaa found: appending data
# Processing Record 84: ribeira brava found: appending data
# Processing Record 85: mairi found: appending data
# Processing Record 86: taolanaro not found: skipping...
# Processing Record 87: hithadhoo found: appending data
# Processing Record 88: hilo found: appending data
# Processing Record 89: new norfolk found: appending data
# Processing Record 90: severo-kurilsk found: appending data
# Processing Record 91: ushuaia found: appending data
# Processing Record 92: kutna hora found: appending data
# Processing Record 93: nouadhibou found: appending data
# Processing Record 94: haverhill found: appending data
# Processing Record 95: pacific grove found: appending data
# Processing Record 96: shingu found: appending data
# Processing Record 97: axim found: appending data
# Processing Record 98: troitsko-pechorsk found: appending data
# Processing Record 99: ribeira grande found: appending data
# Processing Record 100: marang found: appending data
# Processing Record 101: bartica found: appending data
# Processing Record 102: airai found: appending data
# Processing Record 103: nikolskoye found: appending data
# Processing Record 104: sulangan found: appending data
# Processing Record 105: coahuayana found: appending data
# Processing Record 106: pevek found: appending data
# Processing Record 107: hammerfest found: appending data
# Processing Record 108: attawapiskat not found: skipping...
# Processing Record 109: pangkalanbuun found: appending data
# Processing Record 110: semirom found: appending data
# Processing Record 111: acari found: appending data
# Processing Record 112: tuktoyaktuk found: appending data
# Processing Record 113: ponta do sol found: appending data
# Processing Record 114: avera found: appending data
# Processing Record 115: del rio found: appending data
# Processing Record 116: kamina found: appending data
# Processing Record 117: nacala found: appending data
# Processing Record 118: ternate found: appending data
# Processing Record 119: puerto del rosario found: appending data
# Processing Record 120: burica not found: skipping...
# Processing Record 121: manokwari found: appending data
# Processing Record 122: hasaki found: appending data
# Processing Record 123: kitimat found: appending data
# Processing Record 124: honiara found: appending data
# Processing Record 125: tiksi found: appending data
# Processing Record 126: ahuimanu found: appending data
# Processing Record 127: tadine found: appending data
# Processing Record 128: nara found: appending data
# Processing Record 129: victoria found: appending data
# Processing Record 130: solnechnyy found: appending data
# Processing Record 131: vao found: appending data
# Processing Record 132: cabo san lucas found: appending data
# Processing Record 133: vila franca do campo found: appending data
# Processing Record 134: mar del plata found: appending data
# Processing Record 135: inuvik found: appending data
# Processing Record 136: batagay found: appending data
# Processing Record 137: zhaoyuan found: appending data
# Processing Record 138: bethel found: appending data
# Processing Record 139: usinsk found: appending data
# Processing Record 140: talnakh found: appending data
# Processing Record 141: salaga found: appending data
# Processing Record 142: lagoa found: appending data
# Processing Record 143: ca mau found: appending data
# Processing Record 144: tonekabon found: appending data
# Processing Record 145: palana found: appending data
# Processing Record 146: ihosy found: appending data
# Processing Record 147: kpandu found: appending data
# Processing Record 148: sao filipe found: appending data
# Processing Record 149: atar found: appending data
# Processing Record 150: khonuu not found: skipping...
# Processing Record 151: karaul not found: skipping...
# Processing Record 152: tura found: appending data
# Processing Record 153: fereydun kenar found: appending data
# Processing Record 154: ilulissat found: appending data
# Processing Record 155: constitucion found: appending data
# Processing Record 156: samalaeulu not found: skipping...
# Processing Record 157: angatuba found: appending data
# Processing Record 158: mwanza found: appending data
# Processing Record 159: ocho rios found: appending data
# Processing Record 160: portland found: appending data
# Processing Record 161: oulainen found: appending data
# Processing Record 162: shaki found: appending data
# Processing Record 163: gualeguaychu found: appending data
# Processing Record 164: rorvik found: appending data
# Processing Record 165: ostrovnoy found: appending data
# Processing Record 166: nemuro found: appending data
# Processing Record 167: donzdorf found: appending data
# Processing Record 168: narsaq found: appending data
# Processing Record 169: tasiilaq found: appending data
# Processing Record 170: camacha found: appending data
# Processing Record 171: yellowknife found: appending data
# Processing Record 172: ixtapa found: appending data
# Processing Record 173: mount isa found: appending data
# Processing Record 174: urucara found: appending data
# Processing Record 175: barentsburg not found: skipping...
# Processing Record 176: nitra found: appending data
# Processing Record 177: khatanga found: appending data
# Processing Record 178: male found: appending data
# Processing Record 179: warren found: appending data
# Processing Record 180: escuinapa found: appending data
# Processing Record 181: jacmel found: appending data
# Processing Record 182: churapcha found: appending data
# Processing Record 183: shenjiamen found: appending data
# Processing Record 184: prado found: appending data
# Processing Record 185: carnarvon found: appending data
# Processing Record 186: frontera found: appending data
# Processing Record 187: sentyabrskiy not found: skipping...
# Processing Record 188: puerto escondido found: appending data
# Processing Record 189: namatanai found: appending data
# Processing Record 190: thio found: appending data
# Processing Record 191: esperance found: appending data
# Processing Record 192: lata found: appending data
# Processing Record 193: hermanus found: appending data
# Processing Record 194: hobart found: appending data
# Processing Record 195: penzance found: appending data
# Processing Record 196: codrington found: appending data
# Processing Record 197: marystown found: appending data
# Processing Record 198: samusu not found: skipping...
# Processing Record 199: mulege found: appending data
# Processing Record 200: chirongui found: appending data
# Processing Record 201: bahia honda found: appending data
# Processing Record 202: mayo found: appending data
# Processing Record 203: florianopolis found: appending data
# Processing Record 204: grindavik found: appending data
# Processing Record 205: fairlie found: appending data
# Processing Record 206: gat found: appending data
# Processing Record 207: kyzyl-suu found: appending data
# Processing Record 208: isangel found: appending data
# Processing Record 209: jamestown found: appending data
# Processing Record 210: cascais found: appending data
# Processing Record 211: vilhena found: appending data
# Processing Record 212: luby found: appending data
# Processing Record 213: bonavista found: appending data
# Processing Record 214: sataua not found: skipping...
# Processing Record 215: bambous virieux found: appending data
# Processing Record 216: lebu found: appending data
# Processing Record 217: saint-joseph found: appending data
# Processing Record 218: bereda found: appending data
# Processing Record 219: fallon found: appending data
# Processing Record 220: cherskiy found: appending data
# Processing Record 221: general roca found: appending data
# Processing Record 222: san patricio found: appending data
# Processing Record 223: waipawa found: appending data
# Processing Record 224: marcona not found: skipping...
# Processing Record 225: mirnyy found: appending data
# Processing Record 226: wanning found: appending data
# Processing Record 227: la fria found: appending data
# Processing Record 228: madimba found: appending data
# Processing Record 229: faanui found: appending data
# Processing Record 230: rio grande found: appending data
# Processing Record 231: coquimbo found: appending data
# Processing Record 232: chokurdakh found: appending data
# Processing Record 233: christchurch found: appending data
# Processing Record 234: kahului found: appending data
# Processing Record 235: mackay found: appending data
# Processing Record 236: salina cruz found: appending data
# Processing Record 237: turukhansk found: appending data
# Processing Record 238: pestyaki found: appending data
# Processing Record 239: provideniya found: appending data
# Processing Record 240: sitka found: appending data
# Processing Record 241: upernavik found: appending data
# Processing Record 242: tuggurt not found: skipping...
# Processing Record 243: liverpool found: appending data
# Processing Record 244: richmond found: appending data
# Processing Record 245: cidreira found: appending data
# Processing Record 246: necochea found: appending data
# Processing Record 247: raga found: appending data
# Processing Record 248: thaba-tseka found: appending data
# Processing Record 249: drayton valley found: appending data
# Processing Record 250: richards bay found: appending data
# Processing Record 251: gobabis found: appending data
# Processing Record 252: carballo found: appending data
# Processing Record 253: bom sucesso found: appending data
# Processing Record 254: los llanos de aridane found: appending data
# Processing Record 255: jiexiu found: appending data
# Processing Record 256: fairbanks found: appending data
# Processing Record 257: bowen found: appending data
# Processing Record 258: ponferrada found: appending data
# Processing Record 259: alofi found: appending data
# Processing Record 260: voskresenskoye found: appending data
# Processing Record 261: dhaka found: appending data
# Processing Record 262: nantucket found: appending data
# Processing Record 263: isoka found: appending data
# Processing Record 264: tonantins found: appending data
# Processing Record 265: ayaviri found: appending data
# Processing Record 266: kaitangata found: appending data
# Processing Record 267: brae found: appending data
# Processing Record 268: amderma not found: skipping...
# Processing Record 269: rupert found: appending data
# Processing Record 270: baruun-urt found: appending data
# Processing Record 271: pasni found: appending data
# Processing Record 272: beyneu found: appending data
# Processing Record 273: te anau found: appending data
# Processing Record 274: morondava found: appending data
# Processing Record 275: baghdad found: appending data
# Processing Record 276: calvinia found: appending data
# Processing Record 277: urmenis found: appending data
# Processing Record 278: salinopolis found: appending data
# Processing Record 279: college found: appending data
# Processing Record 280: port hardy found: appending data
# Processing Record 281: lavrentiya found: appending data
# Processing Record 282: siocon found: appending data
# Processing Record 283: seydi found: appending data
# Processing Record 284: dombarovskiy found: appending data
# Processing Record 285: barrancas found: appending data
# Processing Record 286: lasa found: appending data
# Processing Record 287: moyale found: appending data
# Processing Record 288: huaicheng found: appending data
# Processing Record 289: uyuni found: appending data
# Processing Record 290: clyde river found: appending data
# Processing Record 291: chiredzi found: appending data
# Processing Record 292: mys shmidta not found: skipping...
# Processing Record 293: ucluelet found: appending data
# Processing Record 294: salalah found: appending data
# Processing Record 295: bati found: appending data
# Processing Record 296: dingle found: appending data
# Processing Record 297: lucapa found: appending data
# Processing Record 298: karasburg found: appending data
# Processing Record 299: angoche found: appending data
# Processing Record 300: yulara found: appending data
# Processing Record 301: chapais found: appending data
# Processing Record 302: magadan found: appending data
# Processing Record 303: nome found: appending data
# Processing Record 304: aranos found: appending data
# Processing Record 305: elverum found: appending data
# Processing Record 306: chesma found: appending data
# Processing Record 307: belmonte found: appending data
# Processing Record 308: furano found: appending data
# Processing Record 309: sur found: appending data
# Processing Record 310: hue found: appending data
# Processing Record 311: vanavara found: appending data
# Processing Record 312: raudeberg found: appending data
# Processing Record 313: hualmay found: appending data
# Processing Record 314: saldanha found: appending data
# Processing Record 315: katano found: appending data
# Processing Record 316: samarai found: appending data
# Processing Record 317: abnub found: appending data
# Processing Record 318: quito found: appending data
# Processing Record 319: sioux lookout found: appending data
# Processing Record 320: kamenskoye not found: skipping...
# Processing Record 321: mocambique not found: skipping...
# Processing Record 322: kamenka found: appending data
# Processing Record 323: laguna found: appending data
# Processing Record 324: abu zabad found: appending data
# Processing Record 325: tsihombe not found: skipping...
# Processing Record 326: alihe found: appending data
# Processing Record 327: xuddur found: appending data
# Processing Record 328: pangody found: appending data
# Processing Record 329: saint george found: appending data
# Processing Record 330: somers point found: appending data
# Processing Record 331: januaria found: appending data
# Processing Record 332: noumea found: appending data
# Processing Record 333: sao joao da barra found: appending data
# Processing Record 334: hamilton found: appending data
# Processing Record 335: kasra not found: skipping...
# Processing Record 336: bay roberts found: appending data
# Processing Record 337: uddevalla found: appending data
# Processing Record 338: thanh hoa found: appending data
# Processing Record 339: kensington found: appending data
# Processing Record 340: kavieng found: appending data
# Processing Record 341: ola found: appending data
# Processing Record 342: tibu found: appending data
# Processing Record 343: komsomolskiy found: appending data
# Processing Record 344: kazachinskoye found: appending data
# Processing Record 345: moerai found: appending data
# Processing Record 346: botwood found: appending data
# Processing Record 347: ullapool found: appending data
# Processing Record 348: vestmannaeyjar found: appending data
# Processing Record 349: sokoni found: appending data
# Processing Record 350: sinnamary found: appending data
# Processing Record 351: sri aman found: appending data
# Processing Record 352: porto novo found: appending data
# Processing Record 353: kenai found: appending data
# Processing Record 354: krasnoselkup found: appending data
# Processing Record 355: vardo found: appending data
# Processing Record 356: albion found: appending data
# Processing Record 357: preobrazheniye found: appending data
# Processing Record 358: quelimane found: appending data
# Processing Record 359: camrose found: appending data
# Processing Record 360: vaitupu not found: skipping...
# Processing Record 361: praia found: appending data
# Processing Record 362: phan rang not found: skipping...
# Processing Record 363: espanola found: appending data
# Processing Record 364: sakaiminato found: appending data
# Processing Record 365: ocosingo found: appending data
# Processing Record 366: ust-tsilma found: appending data
# Processing Record 367: kathu found: appending data
# Processing Record 368: olbernhau found: appending data
# Processing Record 369: rocha found: appending data
# Processing Record 370: upanema found: appending data
# Processing Record 371: dudinka found: appending data
# Processing Record 372: gambo found: appending data
# Processing Record 373: cabedelo found: appending data
# Processing Record 374: sol-iletsk found: appending data
# Processing Record 375: barawe not found: skipping...
# Processing Record 376: sisimiut found: appending data
# Processing Record 377: abilene found: appending data
# Processing Record 378: dabat found: appending data
# Processing Record 379: tamandare found: appending data
# Processing Record 380: la ronge found: appending data
# Processing Record 381: nogliki found: appending data
# Processing Record 382: morar found: appending data
# Processing Record 383: leh found: appending data
# Processing Record 384: shamary found: appending data
# Processing Record 385: pitea found: appending data
# Processing Record 386: camana found: appending data
# Processing Record 387: livingston found: appending data
# Processing Record 388: catamarca found: appending data
# Processing Record 389: etchoropo found: appending data
# Processing Record 390: oksovskiy found: appending data
# Processing Record 391: zhicheng found: appending data
# Processing Record 392: ajdabiya found: appending data
# Processing Record 393: caraubas found: appending data
# Processing Record 394: padampur found: appending data
# Processing Record 395: plastun found: appending data
# Processing Record 396: cayenne found: appending data
# Processing Record 397: mogadishu found: appending data
# Processing Record 398: ulladulla found: appending data
# Processing Record 399: makasar found: appending data
# Processing Record 400: great bend found: appending data
# Processing Record 401: kadykchan not found: skipping...
# Processing Record 402: ozernovskiy found: appending data
# Processing Record 403: kabo found: appending data
# Processing Record 404: okaihau found: appending data
# Processing Record 405: mount gambier found: appending data
# Processing Record 406: malatya found: appending data
# Processing Record 407: antofagasta found: appending data
# Processing Record 408: demyansk found: appending data
# Processing Record 409: edmundston found: appending data
# Processing Record 410: mahadday weyne not found: skipping...
# Processing Record 411: turbat found: appending data
# Processing Record 412: sorvag not found: skipping...
# Processing Record 413: luderitz found: appending data
# Processing Record 414: warqla not found: skipping...
# Processing Record 415: flinders found: appending data
# Processing Record 416: souillac found: appending data
# Processing Record 417: romitan found: appending data
# Processing Record 418: tsiroanomandidy found: appending data
# Processing Record 419: yar-sale found: appending data
# Processing Record 420: arraial do cabo found: appending data
# Processing Record 421: fort wellington found: appending data
# Processing Record 422: bilma found: appending data
# Processing Record 423: ponta delgada found: appending data
# Processing Record 424: oum hadjer found: appending data
# Processing Record 425: krasnokamensk found: appending data
# Processing Record 426: bryant found: appending data
# Processing Record 427: alice springs found: appending data
# Processing Record 428: balvi found: appending data
# Processing Record 429: ukiah found: appending data
# Processing Record 430: puerto asis found: appending data
# Processing Record 431: jalu found: appending data
# Processing Record 432: bandarbeyla found: appending data
# Processing Record 433: guerrero negro found: appending data
# Processing Record 434: shirpur found: appending data
# Processing Record 435: pisco found: appending data
# Processing Record 436: orsha found: appending data
# Processing Record 437: ulaangom found: appending data
# Processing Record 438: talavera de la reina found: appending data
# Processing Record 439: pangoa found: appending data
# Processing Record 440: llanes found: appending data
# Processing Record 441: craig found: appending data
# Processing Record 442: rungata not found: skipping...
# Processing Record 443: kuragino found: appending data
# Processing Record 444: palmer found: appending data
# Processing Record 445: ust-maya found: appending data
# Processing Record 446: erenhot found: appending data
# Processing Record 447: pionerskiy found: appending data
# Processing Record 448: olafsvik found: appending data
# Processing Record 449: anadyr found: appending data
# Processing Record 450: upington found: appending data
# Processing Record 451: eyl found: appending data
# Processing Record 452: kigoma found: appending data
# Processing Record 453: verkhnyaya inta found: appending data
# Processing Record 454: vila found: appending data
# Processing Record 455: ambo found: appending data
# Processing Record 456: launceston found: appending data
# Processing Record 457: abu road found: appending data
# Processing Record 458: sambava found: appending data
# Processing Record 459: norrkoping found: appending data
# Processing Record 460: acarau found: appending data
# Processing Record 461: panama city found: appending data
# Processing Record 462: omboue found: appending data
# Processing Record 463: kendari found: appending data
# Processing Record 464: nanortalik found: appending data
# Processing Record 465: vostok found: appending data
# Processing Record 466: ziro found: appending data
# Processing Record 467: helong found: appending data
# Processing Record 468: cockburn town found: appending data
# Processing Record 469: shellbrook found: appending data
# Processing Record 470: perigueux found: appending data
# Processing Record 471: yebaishou found: appending data
# Processing Record 472: berdigestyakh found: appending data
# Processing Record 473: fortuna found: appending data
# Processing Record 474: fengcheng found: appending data
# Processing Record 475: orgun not found: skipping...
# Processing Record 476: suba found: appending data
# Processing Record 477: ixtiyucan not found: skipping...
# Processing Record 478: hambantota found: appending data
# Processing Record 479: cartagena found: appending data
# Processing Record 480: saint stephen found: appending data
# Processing Record 481: kirakira found: appending data
# Processing Record 482: harper found: appending data
# Processing Record 483: fierze not found: skipping...
# Processing Record 484: khawhai found: appending data
# Processing Record 485: ondjiva found: appending data
# Processing Record 486: la spezia found: appending data
# Processing Record 487: sosnovo-ozerskoye found: appending data
# Processing Record 488: villa carlos paz found: appending data
# Processing Record 489: colombo found: appending data
# Processing Record 490: naryan-mar found: appending data
# Processing Record 491: nyandoma found: appending data
# Processing Record 492: colares found: appending data
# Processing Record 493: varangaon found: appending data
# Processing Record 494: paamiut found: appending data
# Processing Record 495: maldonado found: appending data
# Processing Record 496: ishigaki found: appending data
# Processing Record 497: hosangadi found: appending data
# Processing Record 498: smithers found: appending data
# Processing Record 499: zomin found: appending data
# Processing Record 500: thinadhoo found: appending data
# Processing Record 501: taoudenni found: appending data
# Processing Record 502: cururupu found: appending data
# Processing Record 503: latung found: appending data
# Processing Record 504: port blair found: appending data
# Processing Record 505: comodoro rivadavia found: appending data
# Processing Record 506: teahupoo found: appending data
# Processing Record 507: tateyama found: appending data
# Processing Record 508: manggar found: appending data
# Processing Record 509: valparaiso found: appending data
# Processing Record 510: sann found: appending data
# Processing Record 511: moa found: appending data
# Processing Record 512: korem found: appending data
# Processing Record 513: banda aceh found: appending data
# Processing Record 514: aykhal found: appending data
# Processing Record 515: dakar found: appending data
# Processing Record 516: tuensang found: appending data
# Processing Record 517: pingdingshan found: appending data
# Processing Record 518: san rafael abajo found: appending data
# Processing Record 519: yarmouth found: appending data
# Processing Record 520: charters towers found: appending data
# Processing Record 521: semey found: appending data
# Processing Record 522: ossora found: appending data
# Processing Record 523: savalou found: appending data
# Processing Record 524: port macquarie found: appending data
# Processing Record 525: korla found: appending data
# Processing Record 526: la asuncion found: appending data
# Processing Record 527: rudbar found: appending data
# Processing Record 528: saleaula not found: skipping...
# Processing Record 529: marquette found: appending data
# Processing Record 530: port moresby found: appending data
# Processing Record 531: palabuhanratu not found: skipping...
# Processing Record 532: negombo found: appending data
# Processing Record 533: kungurtug found: appending data
# Processing Record 534: zabid found: appending data
# Processing Record 535: umba found: appending data
# Processing Record 536: mutsamudu not found: skipping...
# Processing Record 537: viloco found: appending data
# Processing Record 538: ekhabi found: appending data
# Processing Record 539: deputatskiy found: appending data
# Processing Record 540: walvis bay found: appending data
# Processing Record 541: pensacola found: appending data
# Processing Record 542: saint-francois found: appending data
# Processing Record 543: praia da vitoria found: appending data
# Processing Record 544: bull savanna found: appending data
# Processing Record 545: sainte-maxime found: appending data
# Processing Record 546: amara found: appending data
# Processing Record 547: mangrol found: appending data
# Processing Record 548: quatre cocos found: appending data
# Processing Record 549: immokalee found: appending data
# Processing Record 550: mecca found: appending data
# Processing Record 551: salamanca found: appending data
# Processing Record 552: yeppoon found: appending data
# Processing Record 553: petropavlovsk-kamchatskiy found: appending data
# Processing Record 554: marawi found: appending data
# Processing Record 555: dunedin found: appending data
# Processing Record 556: kidal found: appending data
# Processing Record 557: labuhan found: appending data
# Processing Record 558: quepos found: appending data
# Processing Record 559: zhigansk found: appending data
# Processing Record 560: araquari found: appending data
# Processing Record 561: rawson found: appending data
# Processing Record 562: grojdibodu found: appending data
# Processing Record 563: panaba found: appending data
# Processing Record 564: toyooka found: appending data
# Processing Record 565: viedma found: appending data
# Processing Record 566: bogande found: appending data
# Processing Record 567: high rock found: appending data
# Processing Record 568: hami found: appending data
# Processing Record 569: cap malheureux found: appending data
# Processing Record 570: meulaboh found: appending data
# Processing Record 571: miranda found: appending data
# Processing Record 572: the pas found: appending data
# Processing Record 573: miandrivazo found: appending data
# Processing Record 574: feijo found: appending data
# Processing Record 575: ostersund found: appending data
# Processing Record 576: roald found: appending data
# Processing Record 577: ouahigouya found: appending data
# Processing Record 578: nouakchott found: appending data
# Processing Record 579: concarneau found: appending data
# Processing Record 580: nabire found: appending data
# Processing Record 581: bambanglipuro found: appending data
# Processing Record 582: grao mogol found: appending data
# Processing Record 583: ampanihy found: appending data
# Processing Record 584: kungsbacka found: appending data
# Processing Record 585: abashiri found: appending data
# Processing Record 586: poum found: appending data
# Processing Record 587: divnoye found: appending data
# Processing Record 588: burnie found: appending data
# Processing Record 589: huangnihe found: appending data
# Processing Record 590: karauzyak not found: skipping...
# Processing Record 591: wuwei found: appending data
# Processing Record 592: emerald found: appending data
# Processing Record 593: cananea found: appending data
# Processing Record 594: westerland found: appending data
# Processing Record 595: angra not found: skipping...
# Processing Record 596: katangli found: appending data
# Processing Record 597: verkhnevilyuysk found: appending data
# Processing Record 598: sakakah found: appending data
# Processing Record 599: arman found: appending data
# Processing Record 600: lolua not found: skipping...
# Data Retrieval Complete

# %%
print(len(found_cities),len(lat),len(temp),len(humidity),len(cloudiness),len(wind_speed))
# Out:
# 556 556 556 556 556 556

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": found_cities,
    "Latitude": lat,
    "Longitude": lon,
    "Temperature": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Maximum Speed": max_temp,
    "Country": country,
    "Time Zone": time_zone,
    "Date and Time": date_and_time
}
weather_data = pd.DataFrame(weather_dict)
weather_data
import os
weather_data.to_csv(os.path.join("output_data_file.csv"))
weather_data
# Out:
#                 City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0     saint-philippe  -21.3585    55.7679        72.54        69           0
# 1       norman wells   65.2820  -126.8329       -18.40        76          75
# 2       port hedland  -20.3167   118.5667        78.80        65          19
# 3           acapulco   16.8634   -99.8901        81.84        63          12
# 4               chuy  -33.6971   -53.4616        78.28        70          99
# ..               ...       ...        ...          ...       ...         ...
# 551       westerland   54.9079     8.3033        33.94        93          75
# 552         katangli   51.7102   143.2326         5.18        94         100
# 553  verkhnevilyuysk   63.4453   120.3167       -51.21        76          82
# 554          sakakah   29.9697    40.2064        48.20        34           0
# 555            arman   59.7000   150.1667        -9.62        82          86
#
#      Wind Speed  Maximum Speed Country  Time Zone  Date and Time
# 0          6.91          75.20      RE      14400     1611703749
# 1          6.67         -18.40      CA     -25200     1611703749
# 2          5.75          78.80      AU      28800     1611703749
# 3          7.94          81.84      MX     -21600     1611703673
# 4          5.14          78.28      UY     -10800     1611703750
# ..          ...            ...     ...        ...            ...
# 551        8.05          35.60      DE       3600     1611703856
# 552        9.17           5.18      RU      39600     1611703856
# 553        3.98         -51.21      RU      32400     1611703856
# 554        3.44          48.20      SA      10800     1611703856
# 555       10.47          -9.62      RU      39600     1611703856
#
# [556 rows x 11 columns]

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship between Latitude and Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInWorldCities.png")

# Show plot
plt.show()

# %%
northern_hemi_df=weather_data[weather_data["Latitude"]>=0]
southern_hemi_df=weather_data[weather_data["Latitude"]<=0]

# %%
# Build a scatter plot for each data type
plt.scatter(northern_hemi_df["Latitude"], northern_hemi_df["Temperature"], marker="o")
plt.scatter(southern_hemi_df["Latitude"], southern_hemi_df["Temperature"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Temperature in the Norther Hemisphere")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("GlobalTempvLatitude.png")

# Show plot
plt.show()

# %%
northern_hemi_df.plot(kind="scatter",x="Latitude",y="Temperature")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Temperature"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
plt.savefig("NorthernHemispherTempvLatitude.png")

southern_hemi_df.plot(kind="scatter",x="Latitude",y="Temperature")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Temperature"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value is: {r}")
# Out:
# The R-Value is: -0.8499600195712567
# The R-Value is: 0.39596065246229484

# %%
southern_hemi_df.plot(kind="scatter",x="Latitude",y="Humidity")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Humidity"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Southern Hemisphere is: {r}")

northern_hemi_df.plot(kind="scatter",x="Latitude",y="Humidity")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Humidity"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
# Out:
# The R-Value for the Southern Hemisphere is: 0.39115470324677254
# The R-Value for the Northern Hemisphere is: 0.3343509716348563

# %%
southern_hemi_df.plot(kind="scatter",x="Latitude",y="Cloudiness")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Cloudiness"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Southern Hemisphere is: {r}")

northern_hemi_df.plot(kind="scatter",x="Latitude",y="Cloudiness")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Cloudiness"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
# Out:
# The R-Value for the Southern Hemisphere is: 0.25864148690019895
# The R-Value for the Northern Hemisphere is: 0.3019552392939388

# %%
southern_hemi_df.plot(kind="scatter",x="Latitude",y="Wind Speed")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Wind Speed"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Southern Hemisphere is: {r}")

northern_hemi_df.plot(kind="scatter",x="Latitude",y="Wind Speed")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Wind Speed"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
# Out:
# The R-Value for the Southern Hemisphere is: -0.2720090865522233
# The R-Value for the Northern Hemisphere is: 0.019956269940271516
