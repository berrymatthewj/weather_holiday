# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
from pprint import pprint
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Import API key
from config import weather_api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_units = "imperial"
#Import API key
# from config import weather_api_key
weather_api_key="dfc2727692557b5a27a7378f50f6abae"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={query_units}&q="

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={query_units}&q="

lat = []
lon = []
max_temp = []
country = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
time_zone = []
date_and_time = []
found_cities=[]

for i, city in enumerate(cities):
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        country.append(response["sys"]["country"])
        time_zone.append(response["timezone"])
        date_and_time.append(response["dt"])
        found_cities.append(city)
        print(f"Processing Record {i+1}: {city} found: appending data")
    except Exception:
        print(f"Processing Record {i+1}: {city} not found: skipping...")
else:
    print("Data Retrieval Complete")
# Out:
# Processing Record 1: dikson found: appending data
# Processing Record 2: andros town found: appending data
# Processing Record 3: bonavista found: appending data
# Processing Record 4: rudnogorsk found: appending data
# Processing Record 5: sao jose da coroa grande found: appending data
# Processing Record 6: natal found: appending data
# Processing Record 7: east london found: appending data
# Processing Record 8: caravelas found: appending data
# Processing Record 9: beloha found: appending data
# Processing Record 10: punta arenas found: appending data
# Processing Record 11: west wendover found: appending data
# Processing Record 12: leningradskiy found: appending data
# Processing Record 13: bluff found: appending data
# Processing Record 14: matara found: appending data
# Processing Record 15: port alfred found: appending data
# Processing Record 16: tasiilaq found: appending data
# Processing Record 17: dolinsk found: appending data
# Processing Record 18: kapaa found: appending data
# Processing Record 19: cidreira found: appending data
# Processing Record 20: thinadhoo found: appending data
# Processing Record 21: jamestown found: appending data
# Processing Record 22: otanche found: appending data
# Processing Record 23: rikitea found: appending data
# Processing Record 24: bredasdorp found: appending data
# Processing Record 25: saint-philippe found: appending data
# Processing Record 26: albany found: appending data
# Processing Record 27: zemio found: appending data
# Processing Record 28: bilibino found: appending data
# Processing Record 29: margate found: appending data
# Processing Record 30: mar del plata found: appending data
# Processing Record 31: hermanus found: appending data
# Processing Record 32: namibe found: appending data
# Processing Record 33: hasaki found: appending data
# Processing Record 34: wuwei found: appending data
# Processing Record 35: paamiut found: appending data
# Processing Record 36: chokurdakh found: appending data
# Processing Record 37: puerto baquerizo moreno found: appending data
# Processing Record 38: belushya guba not found: skipping...
# Processing Record 39: ulladulla found: appending data
# Processing Record 40: ambon found: appending data
# Processing Record 41: pitimbu found: appending data
# Processing Record 42: bethel found: appending data
# Processing Record 43: mon found: appending data
# Processing Record 44: hithadhoo found: appending data
# Processing Record 45: ushuaia found: appending data
# Processing Record 46: nome found: appending data
# Processing Record 47: busselton found: appending data
# Processing Record 48: kavieng found: appending data
# Processing Record 49: mount isa found: appending data
# Processing Record 50: hobart found: appending data
# Processing Record 51: mataura found: appending data
# Processing Record 52: bathsheba found: appending data
# Processing Record 53: price found: appending data
# Processing Record 54: guerrero negro found: appending data
# Processing Record 55: longyearbyen found: appending data
# Processing Record 56: panguna found: appending data
# Processing Record 57: coihaique found: appending data
# Processing Record 58: attawapiskat not found: skipping...
# Processing Record 59: samarai found: appending data
# Processing Record 60: kodiak found: appending data
# Processing Record 61: norman wells found: appending data
# Processing Record 62: ancud found: appending data
# Processing Record 63: butaritari found: appending data
# Processing Record 64: makungu found: appending data
# Processing Record 65: osypenko found: appending data
# Processing Record 66: kupang found: appending data
# Processing Record 67: nuuk found: appending data
# Processing Record 68: louviers found: appending data
# Processing Record 69: bengkulu found: appending data
# Processing Record 70: olafsvik found: appending data
# Processing Record 71: vaini found: appending data
# Processing Record 72: pevek found: appending data
# Processing Record 73: ust-kamchatsk not found: skipping...
# Processing Record 74: sentyabrskiy not found: skipping...
# Processing Record 75: saldanha found: appending data
# Processing Record 76: cape town found: appending data
# Processing Record 77: ambilobe found: appending data
# Processing Record 78: castro found: appending data
# Processing Record 79: tuktoyaktuk found: appending data
# Processing Record 80: esperance found: appending data
# Processing Record 81: fiumicino found: appending data
# Processing Record 82: arraial do cabo found: appending data
# Processing Record 83: kruisfontein found: appending data
# Processing Record 84: kuito found: appending data
# Processing Record 85: luderitz found: appending data
# Processing Record 86: corinth found: appending data
# Processing Record 87: saint-joseph found: appending data
# Processing Record 88: kannod found: appending data
# Processing Record 89: narsaq found: appending data
# Processing Record 90: atuona found: appending data
# Processing Record 91: lebu found: appending data
# Processing Record 92: gizo found: appending data
# Processing Record 93: naze found: appending data
# Processing Record 94: gubkinskiy found: appending data
# Processing Record 95: qaanaaq found: appending data
# Processing Record 96: saint george found: appending data
# Processing Record 97: boundiali found: appending data
# Processing Record 98: tuatapere found: appending data
# Processing Record 99: puerto ayora found: appending data
# Processing Record 100: bilma found: appending data
# Processing Record 101: chapais found: appending data
# Processing Record 102: waingapu found: appending data
# Processing Record 103: saskylakh found: appending data
# Processing Record 104: hilo found: appending data
# Processing Record 105: batsfjord found: appending data
# Processing Record 106: tiksi found: appending data
# Processing Record 107: zhanakorgan found: appending data
# Processing Record 108: khatanga found: appending data
# Processing Record 109: velikiy ustyug found: appending data
# Processing Record 110: baykit found: appending data
# Processing Record 111: mahebourg found: appending data
# Processing Record 112: bulgan found: appending data
# Processing Record 113: ola found: appending data
# Processing Record 114: atar found: appending data
# Processing Record 115: krasnyy yar found: appending data
# Processing Record 116: kota tinggi found: appending data
# Processing Record 117: illoqqortoormiut not found: skipping...
# Processing Record 118: port lincoln found: appending data
# Processing Record 119: bengkalis not found: skipping...
# Processing Record 120: verkhovazhye found: appending data
# Processing Record 121: havelock found: appending data
# Processing Record 122: clyde river found: appending data
# Processing Record 123: yichun found: appending data
# Processing Record 124: college found: appending data
# Processing Record 125: talnakh found: appending data
# Processing Record 126: kabare found: appending data
# Processing Record 127: saleaula not found: skipping...
# Processing Record 128: alofi found: appending data
# Processing Record 129: inuvik found: appending data
# Processing Record 130: gurskoye not found: skipping...
# Processing Record 131: port elizabeth found: appending data
# Processing Record 132: ulaanbaatar found: appending data
# Processing Record 133: ponta do sol found: appending data
# Processing Record 134: shimoda found: appending data
# Processing Record 135: oster found: appending data
# Processing Record 136: westport found: appending data
# Processing Record 137: vanimo found: appending data
# Processing Record 138: roma found: appending data
# Processing Record 139: atambua found: appending data
# Processing Record 140: upernavik found: appending data
# Processing Record 141: lorengau found: appending data
# Processing Record 142: new norfolk found: appending data
# Processing Record 143: cherskiy found: appending data
# Processing Record 144: nara found: appending data
# Processing Record 145: shache found: appending data
# Processing Record 146: fairmont found: appending data
# Processing Record 147: nikolskoye found: appending data
# Processing Record 148: sokolo found: appending data
# Processing Record 149: srednekolymsk found: appending data
# Processing Record 150: taolanaro not found: skipping...
# Processing Record 151: moron found: appending data
# Processing Record 152: ihosy found: appending data
# Processing Record 153: bud found: appending data
# Processing Record 154: kununurra found: appending data
# Processing Record 155: pangody found: appending data
# Processing Record 156: esso found: appending data
# Processing Record 157: temuco found: appending data
# Processing Record 158: takhli found: appending data
# Processing Record 159: ionia found: appending data
# Processing Record 160: thompson found: appending data
# Processing Record 161: los llanos de aridane found: appending data
# Processing Record 162: coahuayana found: appending data
# Processing Record 163: barrow found: appending data
# Processing Record 164: richards bay found: appending data
# Processing Record 165: aklavik found: appending data
# Processing Record 166: samalaeulu not found: skipping...
# Processing Record 167: fortuna found: appending data
# Processing Record 168: kemin found: appending data
# Processing Record 169: boa vista found: appending data
# Processing Record 170: petrovec found: appending data
# Processing Record 171: sitka found: appending data
# Processing Record 172: keroka found: appending data
# Processing Record 173: wewak found: appending data
# Processing Record 174: kysyl-syr found: appending data
# Processing Record 175: lumeje found: appending data
# Processing Record 176: santa maria found: appending data
# Processing Record 177: aketi found: appending data
# Processing Record 178: ilulissat found: appending data
# Processing Record 179: pangnirtung found: appending data
# Processing Record 180: sao joao da barra found: appending data
# Processing Record 181: linqiong found: appending data
# Processing Record 182: umzimvubu not found: skipping...
# Processing Record 183: cabo san lucas found: appending data
# Processing Record 184: lazaro cardenas found: appending data
# Processing Record 185: doha found: appending data
# Processing Record 186: santa rosa found: appending data
# Processing Record 187: wattegama found: appending data
# Processing Record 188: port hedland found: appending data
# Processing Record 189: carnarvon found: appending data
# Processing Record 190: ribeira grande found: appending data
# Processing Record 191: san patricio found: appending data
# Processing Record 192: faya found: appending data
# Processing Record 193: juegang found: appending data
# Processing Record 194: victoria found: appending data
# Processing Record 195: chuy found: appending data
# Processing Record 196: provideniya found: appending data
# Processing Record 197: jinxi found: appending data
# Processing Record 198: avarua found: appending data
# Processing Record 199: kalanwali found: appending data
# Processing Record 200: marzuq found: appending data
# Processing Record 201: marcona not found: skipping...
# Processing Record 202: la serena found: appending data
# Processing Record 203: kazalinsk not found: skipping...
# Processing Record 204: grand river south east not found: skipping...
# Processing Record 205: dolbeau not found: skipping...
# Processing Record 206: vao found: appending data
# Processing Record 207: boende found: appending data
# Processing Record 208: torbay found: appending data
# Processing Record 209: amderma not found: skipping...
# Processing Record 210: quimper found: appending data
# Processing Record 211: reconquista found: appending data
# Processing Record 212: umm lajj found: appending data
# Processing Record 213: stornoway found: appending data
# Processing Record 214: acari found: appending data
# Processing Record 215: tongliao found: appending data
# Processing Record 216: bambous virieux found: appending data
# Processing Record 217: meyungs not found: skipping...
# Processing Record 218: yulara found: appending data
# Processing Record 219: chagda not found: skipping...
# Processing Record 220: chardara found: appending data
# Processing Record 221: labytnangi found: appending data
# Processing Record 222: sangar found: appending data
# Processing Record 223: senneterre found: appending data
# Processing Record 224: hastings found: appending data
# Processing Record 225: warrnambool found: appending data
# Processing Record 226: guane found: appending data
# Processing Record 227: rio gallegos found: appending data
# Processing Record 228: samusu not found: skipping...
# Processing Record 229: slavyanka found: appending data
# Processing Record 230: san cristobal found: appending data
# Processing Record 231: georgetown found: appending data
# Processing Record 232: olinda found: appending data
# Processing Record 233: mangan found: appending data
# Processing Record 234: vardo found: appending data
# Processing Record 235: grindavik found: appending data
# Processing Record 236: kavaratti found: appending data
# Processing Record 237: sakakah found: appending data
# Processing Record 238: adelaide found: appending data
# Processing Record 239: khuzhir found: appending data
# Processing Record 240: puerto escondido found: appending data
# Processing Record 241: ciudad bolivar found: appending data
# Processing Record 242: duz not found: skipping...
# Processing Record 243: winnemucca found: appending data
# Processing Record 244: ahipara found: appending data
# Processing Record 245: thunder bay found: appending data
# Processing Record 246: talaya found: appending data
# Processing Record 247: isla vista found: appending data
# Processing Record 248: mondlo found: appending data
# Processing Record 249: denpasar found: appending data
# Processing Record 250: faanui found: appending data
# Processing Record 251: yellowknife found: appending data
# Processing Record 252: harper found: appending data
# Processing Record 253: khasan found: appending data
# Processing Record 254: anar darreh not found: skipping...
# Processing Record 255: sao filipe found: appending data
# Processing Record 256: lolua not found: skipping...
# Processing Record 257: mbini found: appending data
# Processing Record 258: dwarka found: appending data
# Processing Record 259: mineiros found: appending data
# Processing Record 260: barentsburg not found: skipping...
# Processing Record 261: vallenar found: appending data
# Processing Record 262: katsuura found: appending data
# Processing Record 263: linjiang found: appending data
# Processing Record 264: amapa found: appending data
# Processing Record 265: rawson found: appending data
# Processing Record 266: maarianhamina found: appending data
# Processing Record 267: nanortalik found: appending data
# Processing Record 268: husavik found: appending data
# Processing Record 269: eyl found: appending data
# Processing Record 270: ucluelet found: appending data
# Processing Record 271: badarpur found: appending data
# Processing Record 272: beba found: appending data
# Processing Record 273: ponta delgada found: appending data
# Processing Record 274: buston found: appending data
# Processing Record 275: baiyin found: appending data
# Processing Record 276: wanning found: appending data
# Processing Record 277: pisco found: appending data
# Processing Record 278: tsihombe not found: skipping...
# Processing Record 279: novi banovci found: appending data
# Processing Record 280: mayor pablo lagerenza found: appending data
# Processing Record 281: mudkhed found: appending data
# Processing Record 282: sylvan lake found: appending data
# Processing Record 283: ruatoria not found: skipping...
# Processing Record 284: somerset west found: appending data
# Processing Record 285: ahuimanu found: appending data
# Processing Record 286: sisimiut found: appending data
# Processing Record 287: padang found: appending data
# Processing Record 288: yudong found: appending data
# Processing Record 289: oudtshoorn found: appending data
# Processing Record 290: adrar found: appending data
# Processing Record 291: huanren found: appending data
# Processing Record 292: broken hill found: appending data
# Processing Record 293: yanggu found: appending data
# Processing Record 294: popondetta found: appending data
# Processing Record 295: okhotsk found: appending data
# Processing Record 296: evensk found: appending data
# Processing Record 297: vagur found: appending data
# Processing Record 298: barra patuca found: appending data
# Processing Record 299: tadine found: appending data
# Processing Record 300: zaraza found: appending data
# Processing Record 301: bereznik found: appending data
# Processing Record 302: kondagaon found: appending data
# Processing Record 303: bajo baudo not found: skipping...
# Processing Record 304: tazovskiy found: appending data
# Processing Record 305: galiwinku not found: skipping...
# Processing Record 306: lagoa found: appending data
# Processing Record 307: ndola found: appending data
# Processing Record 308: bumba found: appending data
# Processing Record 309: huarmey found: appending data
# Processing Record 310: verkhniy avzyan found: appending data
# Processing Record 311: taoudenni found: appending data
# Processing Record 312: vasto found: appending data
# Processing Record 313: fort nelson found: appending data
# Processing Record 314: kabinda found: appending data
# Processing Record 315: bodden town found: appending data
# Processing Record 316: turbat found: appending data
# Processing Record 317: valmiera found: appending data
# Processing Record 318: lompoc found: appending data
# Processing Record 319: iranshahr found: appending data
# Processing Record 320: airai found: appending data
# Processing Record 321: tianpeng found: appending data
# Processing Record 322: nizhneyansk not found: skipping...
# Processing Record 323: do gonbadan found: appending data
# Processing Record 324: iqaluit found: appending data
# Processing Record 325: camana found: appending data
# Processing Record 326: rio tercero found: appending data
# Processing Record 327: roald found: appending data
# Processing Record 328: codrington found: appending data
# Processing Record 329: canakkale found: appending data
# Processing Record 330: mokhsogollokh found: appending data
# Processing Record 331: kegayli not found: skipping...
# Processing Record 332: kidal found: appending data
# Processing Record 333: wloclawek found: appending data
# Processing Record 334: ketchikan found: appending data
# Processing Record 335: flin flon found: appending data
# Processing Record 336: beringovskiy found: appending data
# Processing Record 337: ostrovnoy found: appending data
# Processing Record 338: angoche found: appending data
# Processing Record 339: grand gaube found: appending data
# Processing Record 340: laguna found: appending data
# Processing Record 341: teya found: appending data
# Processing Record 342: caucaia found: appending data
# Processing Record 343: umm kaddadah found: appending data
# Processing Record 344: baoshan found: appending data
# Processing Record 345: marawi found: appending data
# Processing Record 346: catanduva found: appending data
# Processing Record 347: daxian not found: skipping...
# Processing Record 348: tual found: appending data
# Processing Record 349: haines junction found: appending data
# Processing Record 350: palabuhanratu not found: skipping...
# Processing Record 351: oytal found: appending data
# Processing Record 352: wageningen found: appending data
# Processing Record 353: brahmapuri not found: skipping...
# Processing Record 354: meulaboh found: appending data
# Processing Record 355: petropavlovsk-kamchatskiy found: appending data
# Processing Record 356: olindina found: appending data
# Processing Record 357: hovd found: appending data
# Processing Record 358: sangmelima found: appending data
# Processing Record 359: pafos found: appending data
# Processing Record 360: vila franca do campo found: appending data
# Processing Record 361: lavrentiya found: appending data
# Processing Record 362: kloulklubed found: appending data
# Processing Record 363: buala found: appending data
# Processing Record 364: port-gentil found: appending data
# Processing Record 365: kisangani found: appending data
# Processing Record 366: bandundu found: appending data
# Processing Record 367: midland found: appending data
# Processing Record 368: shalakusha found: appending data
# Processing Record 369: suntar found: appending data
# Processing Record 370: itarema found: appending data
# Processing Record 371: hofn found: appending data
# Processing Record 372: lapeer found: appending data
# Processing Record 373: nouadhibou found: appending data
# Processing Record 374: vestmannaeyjar found: appending data
# Processing Record 375: tubuala found: appending data
# Processing Record 376: gushikawa found: appending data
# Processing Record 377: quatre cocos found: appending data
# Processing Record 378: sorvag not found: skipping...
# Processing Record 379: namatanai found: appending data
# Processing Record 380: kajaani found: appending data
# Processing Record 381: bereda found: appending data
# Processing Record 382: san jeronimo found: appending data
# Processing Record 383: tateyama found: appending data
# Processing Record 384: the pas found: appending data
# Processing Record 385: whyalla found: appending data
# Processing Record 386: manado found: appending data
# Processing Record 387: bandar-e lengeh found: appending data
# Processing Record 388: urdzhar not found: skipping...
# Processing Record 389: korla found: appending data
# Processing Record 390: pringsewu found: appending data
# Processing Record 391: madarounfa found: appending data
# Processing Record 392: verkhnyaya toyma found: appending data
# Processing Record 393: port blair found: appending data
# Processing Record 394: alice springs found: appending data
# Processing Record 395: tacuarembo found: appending data
# Processing Record 396: shubarshi found: appending data
# Processing Record 397: novikovo found: appending data
# Processing Record 398: mocambique not found: skipping...
# Processing Record 399: leshukonskoye found: appending data
# Processing Record 400: tecoanapa found: appending data
# Processing Record 401: xadani not found: skipping...
# Processing Record 402: saquarema found: appending data
# Processing Record 403: yarmouth found: appending data
# Processing Record 404: urfa not found: skipping...
# Processing Record 405: kathu found: appending data
# Processing Record 406: sai buri found: appending data
# Processing Record 407: puerto quijarro found: appending data
# Processing Record 408: guiratinga found: appending data
# Processing Record 409: constitucion found: appending data
# Processing Record 410: bargal not found: skipping...
# Processing Record 411: dunedin found: appending data
# Processing Record 412: tiruvottiyur not found: skipping...
# Processing Record 413: aswan found: appending data
# Processing Record 414: san rafael found: appending data
# Processing Record 415: dingle found: appending data
# Processing Record 416: nortelandia found: appending data
# Processing Record 417: kalakamati found: appending data
# Processing Record 418: salalah found: appending data
# Processing Record 419: safaga found: appending data
# Processing Record 420: senno found: appending data
# Processing Record 421: lagunas found: appending data
# Processing Record 422: kaitangata found: appending data
# Processing Record 423: mujiayingzi found: appending data
# Processing Record 424: severo-yeniseyskiy found: appending data
# Processing Record 425: omsukchan found: appending data
# Processing Record 426: mercedes found: appending data
# Processing Record 427: makakilo city found: appending data
# Processing Record 428: mestia found: appending data
# Processing Record 429: jacareacanga found: appending data
# Processing Record 430: muli found: appending data
# Processing Record 431: potam found: appending data
# Processing Record 432: wasilla found: appending data
# Processing Record 433: raudeberg found: appending data
# Processing Record 434: rawannawi not found: skipping...
# Processing Record 435: qaqortoq found: appending data
# Processing Record 436: honiara found: appending data
# Processing Record 437: geraldton found: appending data
# Processing Record 438: lubao found: appending data
# Processing Record 439: miracema do tocantins found: appending data
# Processing Record 440: ust-kuyga found: appending data
# Processing Record 441: pathein found: appending data
# Processing Record 442: marondera found: appending data
# Processing Record 443: melilla found: appending data
# Processing Record 444: pekalongan found: appending data
# Processing Record 445: la ronge found: appending data
# Processing Record 446: eugene found: appending data
# Processing Record 447: rusape found: appending data
# Processing Record 448: cartagena found: appending data
# Processing Record 449: vaitupu not found: skipping...
# Processing Record 450: cordoba found: appending data
# Processing Record 451: conversion found: appending data
# Processing Record 452: lasa found: appending data
# Processing Record 453: nizhniy tsasuchey found: appending data
# Processing Record 454: yerbogachen found: appending data
# Processing Record 455: ambodifototra not found: skipping...
# Processing Record 456: grand-lahou found: appending data
# Processing Record 457: coihueco found: appending data
# Processing Record 458: avera found: appending data
# Processing Record 459: septemvri found: appending data
# Processing Record 460: fairbanks found: appending data
# Processing Record 461: agadez found: appending data
# Processing Record 462: vila velha found: appending data
# Processing Record 463: malgrat de mar found: appending data
# Processing Record 464: lata found: appending data
# Processing Record 465: marystown found: appending data
# Processing Record 466: nurota found: appending data
# Processing Record 467: vertientes found: appending data
# Processing Record 468: aksha found: appending data
# Processing Record 469: lakhtar found: appending data
# Processing Record 470: mayumba found: appending data
# Processing Record 471: vilhena found: appending data
# Processing Record 472: ornskoldsvik found: appending data
# Processing Record 473: ylivieska found: appending data
# Processing Record 474: pomabamba found: appending data
# Processing Record 475: bontang found: appending data
# Processing Record 476: champerico found: appending data
# Processing Record 477: beidao found: appending data
# Processing Record 478: karakol found: appending data
# Processing Record 479: quelimane found: appending data
# Processing Record 480: carutapera found: appending data
# Processing Record 481: flinders found: appending data
# Processing Record 482: kenora found: appending data
# Processing Record 483: boueni found: appending data
# Processing Record 484: souillac found: appending data
# Processing Record 485: nagaur found: appending data
# Processing Record 486: itape found: appending data
# Processing Record 487: grand-santi found: appending data
# Processing Record 488: saint-ambroise found: appending data
# Processing Record 489: basco found: appending data
# Processing Record 490: tiznit found: appending data
# Processing Record 491: mys shmidta not found: skipping...
# Processing Record 492: sao felix do xingu found: appending data
# Processing Record 493: klaksvik found: appending data
# Processing Record 494: akyab found: appending data
# Processing Record 495: jiexiu found: appending data
# Processing Record 496: umkomaas found: appending data
# Processing Record 497: mizdah found: appending data
# Processing Record 498: sencha found: appending data
# Processing Record 499: miraflores found: appending data
# Processing Record 500: rosarito found: appending data
# Processing Record 501: kakamega found: appending data
# Processing Record 502: lakatoro found: appending data
# Processing Record 503: katangli found: appending data
# Processing Record 504: kushiro found: appending data
# Processing Record 505: jati found: appending data
# Processing Record 506: praia da vitoria found: appending data
# Processing Record 507: huntingdon found: appending data
# Processing Record 508: dargaville found: appending data
# Processing Record 509: hami found: appending data
# Processing Record 510: rocha found: appending data
# Processing Record 511: shunyi found: appending data
# Processing Record 512: kharp found: appending data
# Processing Record 513: yabrud found: appending data
# Processing Record 514: wulanhaote not found: skipping...
# Processing Record 515: fountain hills found: appending data
# Processing Record 516: heihe found: appending data
# Processing Record 517: colares found: appending data
# Processing Record 518: rungata not found: skipping...
# Processing Record 519: feijo found: appending data
# Processing Record 520: jiujiang found: appending data
# Processing Record 521: jinka found: appending data
# Processing Record 522: caramay found: appending data
# Processing Record 523: alexandria found: appending data
# Processing Record 524: zhangjiakou found: appending data
# Processing Record 525: bardiyah found: appending data
# Processing Record 526: taksimo found: appending data
# Processing Record 527: fremont found: appending data
# Processing Record 528: kupino found: appending data
# Processing Record 529: saint-pierre found: appending data
# Processing Record 530: ijaki not found: skipping...
# Processing Record 531: belmonte found: appending data
# Processing Record 532: baijiantan found: appending data
# Processing Record 533: gat found: appending data
# Processing Record 534: kuche not found: skipping...
# Processing Record 535: naryan-mar found: appending data
# Processing Record 536: zhaoyuan found: appending data
# Processing Record 537: el campo found: appending data
# Processing Record 538: noyabrsk found: appending data
# Processing Record 539: murray found: appending data
# Processing Record 540: filadelfia found: appending data
# Processing Record 541: poum found: appending data
# Processing Record 542: hibbing found: appending data
# Processing Record 543: cochrane found: appending data
# Processing Record 544: boyolangu found: appending data
# Processing Record 545: jaguariaiva found: appending data
# Processing Record 546: englehart found: appending data
# Processing Record 547: broome found: appending data
# Processing Record 548: tucuma found: appending data
# Processing Record 549: kandrian found: appending data
# Processing Record 550: shahr-e babak found: appending data
# Processing Record 551: tukrah found: appending data
# Processing Record 552: uruana found: appending data
# Processing Record 553: komsomolskiy found: appending data
# Processing Record 554: labuhan found: appending data
# Processing Record 555: sorland found: appending data
# Processing Record 556: vicuna found: appending data
# Processing Record 557: ranipur found: appending data
# Processing Record 558: sistranda found: appending data
# Processing Record 559: svetlaya found: appending data
# Processing Record 560: cortez found: appending data
# Processing Record 561: kharan found: appending data
# Processing Record 562: hirna found: appending data
# Processing Record 563: henties bay found: appending data
# Processing Record 564: altamont found: appending data
# Processing Record 565: quartucciu found: appending data
# Processing Record 566: lakes entrance found: appending data
# Processing Record 567: sobolevo found: appending data
# Processing Record 568: jacksonville found: appending data
# Processing Record 569: ojinaga found: appending data
# Processing Record 570: the valley found: appending data
# Processing Record 571: port macquarie found: appending data
# Processing Record 572: voh found: appending data
# Processing Record 573: uglekamensk found: appending data
# Processing Record 574: anaconda found: appending data
# Processing Record 575: tumannyy not found: skipping...
# Processing Record 576: oranjestad found: appending data
# Processing Record 577: sao raimundo das mangabeiras found: appending data
# Processing Record 578: landeck found: appending data
# Processing Record 579: alekseyevskoye found: appending data
# Processing Record 580: yushu found: appending data
# Processing Record 581: hamilton found: appending data
# Processing Record 582: karaul not found: skipping...
# Processing Record 583: cairns found: appending data
# Processing Record 584: candolim found: appending data
# Processing Record 585: bandarbeyla found: appending data
# Processing Record 586: mvuma found: appending data
# Processing Record 587: tatarskaya pishlya found: appending data
# Processing Record 588: kashi found: appending data
# Processing Record 589: camocim found: appending data
# Processing Record 590: bocaranga not found: skipping...
# Processing Record 591: havre-saint-pierre found: appending data
# Processing Record 592: nantucket found: appending data
# Processing Record 593: porto walter found: appending data
# Processing Record 594: isangel found: appending data
# Processing Record 595: bosanska dubica found: appending data
# Processing Record 596: khipro found: appending data
# Processing Record 597: iralaya found: appending data
# Processing Record 598: akom found: appending data
# Processing Record 599: svetlogorsk found: appending data
# Processing Record 600: rentina found: appending data
# Processing Record 601: zafra found: appending data
# Processing Record 602: kieta found: appending data
# Processing Record 603: jimeta found: appending data
# Processing Record 604: ranot found: appending data
# Processing Record 605: blagoyevo found: appending data
# Processing Record 606: farap found: appending data
# Processing Record 607: pauini found: appending data
# Processing Record 608: lanzhou found: appending data
# Processing Record 609: egvekinot found: appending data
# Processing Record 610: goiatuba found: appending data
# Data Retrieval Complete

# %%
print(len(found_cities),len(lat),len(temp),len(humidity),len(cloudiness),len(wind_speed))
# Out:
# 560 560 560 560 560 560

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": found_cities,
    "Latitude": lat,
    "Longitude": lon,
    "Temperature": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Maximum Speed": max_temp,
    "Country": country,
    "Time Zone": time_zone,
    "Date and Time": date_and_time,
    "Maximum Temperature": max_temp
}
weather_data_with_humidity = pd.DataFrame(weather_dict)
import os
weather_data_with_humidity.to_csv(os.path.join("output_data_file.csv"))
weather_data_with_humidity
# Out:
#                          City  Latitude  Longitude  Temperature  Humidity  \
# 0                      dikson   73.5069    80.5464       -21.69        86
# 1                 andros town   24.7000   -77.7667        78.80        78
# 2                   bonavista   48.6499   -53.1147        27.39        93
# 3                  rudnogorsk   57.2639   103.7519       -24.45        85
# 4    sao jose da coroa grande   -8.8978   -35.1478        81.37        74
# ..                        ...       ...        ...          ...       ...
# 555                     farap   39.1704    63.6116        33.80        86
# 556                    pauini   -7.7136   -66.9764        86.97        58
# 557                   lanzhou   36.0564   103.7922        26.01        51
# 558                 egvekinot   66.3167  -179.1667       -13.97        87
# 559                  goiatuba  -18.0125   -49.3547        82.53        63
#
#      Cloudiness  Wind Speed  Maximum Speed Country  Time Zone  Date and Time  \
# 0           100        8.39         -21.69      RU      25200     1611771322
# 1            40       13.80          78.80      BS     -18000     1611771470
# 2            81        3.44          28.99      CA     -12600     1611771179
# 3           100        3.89         -24.45      RU      28800     1611771470
# 4            91       11.05          81.37      BR     -10800     1611771470
# ..          ...         ...            ...     ...        ...            ...
# 555           0        4.61          33.80      TM      18000     1611771562
# 556          99        3.83          86.97      BR     -14400     1611771562
# 557           0        1.16          26.01      CN      28800     1611771562
# 558         100       19.98         -13.97      RU      43200     1611771435
# 559          98        6.67          82.53      BR     -10800     1611771562
#
#      Maximum Temperature
# 0                 -21.69
# 1                  78.80
# 2                  28.99
# 3                 -24.45
# 4                  81.37
# ..                   ...
# 555                33.80
# 556                86.97
# 557                26.01
# 558               -13.97
# 559                82.53
#
# [560 rows x 12 columns]

# %% [markdown]
# Inspect the data and remove the cities where the humidity > 100%.

# %%
weather_data_without_humidity=weather_data_with_humidity[weather_data_with_humidity["Humidity"]<=100]
weather_data_without_humidity
# Out:
#                          City  Latitude  Longitude  Temperature  Humidity  \
# 0                      dikson   73.5069    80.5464       -21.69        86
# 1                 andros town   24.7000   -77.7667        78.80        78
# 2                   bonavista   48.6499   -53.1147        27.39        93
# 3                  rudnogorsk   57.2639   103.7519       -24.45        85
# 4    sao jose da coroa grande   -8.8978   -35.1478        81.37        74
# ..                        ...       ...        ...          ...       ...
# 555                     farap   39.1704    63.6116        33.80        86
# 556                    pauini   -7.7136   -66.9764        86.97        58
# 557                   lanzhou   36.0564   103.7922        26.01        51
# 558                 egvekinot   66.3167  -179.1667       -13.97        87
# 559                  goiatuba  -18.0125   -49.3547        82.53        63
#
#      Cloudiness  Wind Speed  Maximum Speed Country  Time Zone  Date and Time  \
# 0           100        8.39         -21.69      RU      25200     1611771322
# 1            40       13.80          78.80      BS     -18000     1611771470
# 2            81        3.44          28.99      CA     -12600     1611771179
# 3           100        3.89         -24.45      RU      28800     1611771470
# 4            91       11.05          81.37      BR     -10800     1611771470
# ..          ...         ...            ...     ...        ...            ...
# 555           0        4.61          33.80      TM      18000     1611771562
# 556          99        3.83          86.97      BR     -14400     1611771562
# 557           0        1.16          26.01      CN      28800     1611771562
# 558         100       19.98         -13.97      RU      43200     1611771435
# 559          98        6.67          82.53      BR     -10800     1611771562
#
#      Maximum Temperature
# 0                 -21.69
# 1                  78.80
# 2                  28.99
# 3                 -24.45
# 4                  81.37
# ..                   ...
# 555                33.80
# 556                86.97
# 557                26.01
# 558               -13.97
# 559                82.53
#
# [560 rows x 12 columns]

# %%
z_scores = stats.zscore(weather_data_without_humidity[["Humidity"]])
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores > 3).all(axis=1)
humidity_outlier_df = weather_data_without_humidity[filtered_entries]
humidity_outlier_df
# Out:
#            City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 92    boundiali    9.5217    -6.4869        90.34        12          29
# 109        atar   20.5169   -13.0499        85.73        11           0
# 139      sokolo   14.7328    -6.1219        84.31        10           0
# 291   iranshahr   27.2025    60.6848        51.80        11           0
# 356  madarounfa   13.3087     7.1560        89.60         6           0
# 403  pekalongan   -6.8886   109.6753        57.99        10         100
#
#      Wind Speed  Maximum Speed Country  Time Zone  Date and Time  \
# 92         3.80          90.34      CI          0     1611771371
# 109       11.34          85.73      MR          0     1611771486
# 139        9.35          84.31      ML          0     1611771492
# 291        1.97          51.80      IR      12600     1611771375
# 356       11.50          89.60      NE       3600     1611771529
# 403        6.53          57.99      ID      25200     1611771537
#
#      Maximum Temperature
# 92                 90.34
# 109                85.73
# 139                84.31
# 291                51.80
# 356                89.60
# 403                57.99

# %%
z_scores = stats.zscore(weather_data_without_humidity[["Humidity"]])
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
weather_data = weather_data_without_humidity[filtered_entries]
weather_data.to_csv(os.path.join("clean_output_data_file.csv"))
weather_data
# Out:
#                          City  Latitude  Longitude  Temperature  Humidity  \
# 0                      dikson   73.5069    80.5464       -21.69        86
# 1                 andros town   24.7000   -77.7667        78.80        78
# 2                   bonavista   48.6499   -53.1147        27.39        93
# 3                  rudnogorsk   57.2639   103.7519       -24.45        85
# 4    sao jose da coroa grande   -8.8978   -35.1478        81.37        74
# ..                        ...       ...        ...          ...       ...
# 555                     farap   39.1704    63.6116        33.80        86
# 556                    pauini   -7.7136   -66.9764        86.97        58
# 557                   lanzhou   36.0564   103.7922        26.01        51
# 558                 egvekinot   66.3167  -179.1667       -13.97        87
# 559                  goiatuba  -18.0125   -49.3547        82.53        63
#
#      Cloudiness  Wind Speed  Maximum Speed Country  Time Zone  Date and Time  \
# 0           100        8.39         -21.69      RU      25200     1611771322
# 1            40       13.80          78.80      BS     -18000     1611771470
# 2            81        3.44          28.99      CA     -12600     1611771179
# 3           100        3.89         -24.45      RU      28800     1611771470
# 4            91       11.05          81.37      BR     -10800     1611771470
# ..          ...         ...            ...     ...        ...            ...
# 555           0        4.61          33.80      TM      18000     1611771562
# 556          99        3.83          86.97      BR     -14400     1611771562
# 557           0        1.16          26.01      CN      28800     1611771562
# 558         100       19.98         -13.97      RU      43200     1611771435
# 559          98        6.67          82.53      BR     -10800     1611771562
#
#      Maximum Temperature
# 0                 -21.69
# 1                  78.80
# 2                  28.99
# 3                 -24.45
# 4                  81.37
# ..                   ...
# 555                33.80
# 556                86.97
# 557                26.01
# 558               -13.97
# 559                82.53
#
# [554 rows x 12 columns]

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Maximum Temperature"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship between Latitude and Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInWorldCities.png")

# Show plot
plt.show()

# %%
northern_hemi_df=weather_data[weather_data["Latitude"]>=0]
southern_hemi_df=weather_data[weather_data["Latitude"]<=0]

# %%
# Build a scatter plot for each data type
plt.scatter(northern_hemi_df["Latitude"], northern_hemi_df["Maximum Temperature"], marker="o")
plt.scatter(southern_hemi_df["Latitude"], southern_hemi_df["Maximum Temperature"], marker="o")

# Incorporate the other graph properties
plt.title("Relationship Between Latitude and Temperature in the Norther Hemisphere")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("GlobalTempvLatitude.png")

# Show plot
plt.show()

# %%
northern_hemi_df.plot(kind="scatter",x="Latitude",y="Maximum Temperature")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Maximum Temperature"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
plt.savefig("NorthernHemispherTempvLatitude.png")

southern_hemi_df.plot(kind="scatter",x="Latitude",y="Maximum Temperature")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Maximum Temperature"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value is: {r}")
# Out:
# The R-Value for the Northern Hemisphere is: -0.8538085207891232
# The R-Value is: 0.5366219958189522

# %%
southern_hemi_df.plot(kind="scatter",x="Latitude",y="Humidity")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Humidity"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Southern Hemisphere is: {r}")

northern_hemi_df.plot(kind="scatter",x="Latitude",y="Humidity")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Humidity"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
# Out:
# The R-Value for the Southern Hemisphere is: 0.26887661438753885
# The R-Value for the Northern Hemisphere is: 0.3439701827800319

# %%
southern_hemi_df.plot(kind="scatter",x="Latitude",y="Cloudiness")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Cloudiness"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Southern Hemisphere is: {r}")

northern_hemi_df.plot(kind="scatter",x="Latitude",y="Cloudiness")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Cloudiness"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
# Out:
# The R-Value for the Southern Hemisphere is: 0.22601331940976524
# The R-Value for the Northern Hemisphere is: 0.30802576065311926

# %%
southern_hemi_df.plot(kind="scatter",x="Latitude",y="Wind Speed")
x=southern_hemi_df['Latitude']
y=southern_hemi_df["Wind Speed"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Southern Hemisphere is: {r}")

northern_hemi_df.plot(kind="scatter",x="Latitude",y="Wind Speed")
x=northern_hemi_df['Latitude']
y=northern_hemi_df["Wind Speed"]
(slope, intercept, r, p, stderr)=stats.linregress(x, y)
y_predict=slope*x+intercept
plt.plot(x,y_predict,color="r")
plt.show
print(f"The R-Value for the Northern Hemisphere is: {r}")
# Out:
# The R-Value for the Southern Hemisphere is: -0.24636571233344642
# The R-Value for the Northern Hemisphere is: 0.04685704186157374
